# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split,GridSearchCV,RandomizedSearchCV
from sklearn.tree import DecisionTreeClassifier,plot_tree
from sklearn.metrics import confusion_matrix,classification_report,roc_auc_score,roc_curve,accuracy_score
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Decision Tree

# %%
df=pd.read_csv(r'D:\Python\Class Practice\Machine learning\Dataset\diabetes.csv')

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
x=df.drop(['Outcome'],axis=1)
y=df[['Outcome']]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
decision_tree=DecisionTreeClassifier()
train_data=decision_tree.fit(x_train,y_train)
train_data
# Out:
# DecisionTreeClassifier()

# %%
y_test_pred_dt=decision_tree.predict(x_test)

# %%
confusion_matrix(y_test,y_test_pred_dt)
# Out:
# array([[87, 20],
#        [16, 31]], dtype=int64)

# %%
accuracy_score(y_test,y_test_pred_dt)
# Out:
# 0.7662337662337663

# %%
# to ckeck the accuracy on train dataa
y_train_pred_dt=decision_tree.predict(x_train)

# %%
accuracy_score(y_train,y_train_pred_dt)
# Out:
# 1.0

# %%
# overfitting problem reemove by hyperparameter
dt = DecisionTreeClassifier()
hyperparameter = {'criterion' : ['entropy','gini'], 'max_depth' : list(range(2,10,2)) }
hyperparameter
# clf = GridSearchCV( dt, hyperparameter , cv =5)
clf2 = RandomizedSearchCV( dt, hyperparameter , cv =5)

best_model = clf2.fit(x_train, y_train)

# %%
best_model.best_params_
# Out:
# {'max_depth': 2, 'criterion': 'gini'}

# %%
y_best_pred_dt=best_model.predict(x_test)

# %%
accuracy_score(y_test,y_best_pred_dt)
# Out:
# 0.7597402597402597

# %%
y_best_train_pred_dt=best_model.predict(x_train)

# %%
accuracy_score(y_train,y_best_train_pred_dt)
# Out:
# 0.7638436482084691

# %%
plt.figure(figsize=(100,70))
plot_tree(decision_tree,filled=True,class_names=x.columns)
# export_graphviz(best_model)
# Out:
# [Text(2274.7218749999997, 3669.2999999999997, 'X[1] <= 0.082\ngini = 0.461\nsamples = 614\nvalue = [393, 221]\nclass = Pregnancies'),
#  Text(798.6374999999999, 3397.5, 'X[7] <= -0.403\ngini = 0.301\nsamples = 352\nvalue = [287, 65]\nclass = Pregnancies'),
#  Text(306.9, 3125.7, 'X[5] <= -0.132\ngini = 0.162\nsamples = 202\nvalue = [184, 18]\nclass = Pregnancies'),
#  Text(167.39999999999998, 2853.8999999999996, 'X[0] <= 0.937\ngini = 0.036\nsamples = 110\nvalue = [108, 2]\nclass = Pregnancies'),
#  Text(111.6, 2582.0999999999995, 'X[6] <= 0.604\ngini = 0.018\nsamples = 109\nvalue = [108, 1]\nclass = Pregnancies'),
#  Text(55.8, 2310.2999999999997, 'gini = 0.0\nsamples = 99\nvalue = [99, 0]\nclass = Pregnancies'),
#  Text(167.39999999999998, 2310.2999999999997, 'X[6] <= 0.681\ngini = 0.18\nsamples = 10\nvalue = [9, 1]\nclass = Pregnancies'),
#  Text(111.6, 2038.4999999999998, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Glucose'),
#  Text(223.2, 2038.4999999999998, 'gini = 0.0\nsamples = 9\nvalue = [9, 0]\nclass = Pregnancies'),
#  Text(223.2, 2582.0999999999995, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Glucose'),
#  Text(446.4, 2853.8999999999996, 'X[2] <= -0.833\ngini = 0.287\nsamples = 92\nvalue = [76, 16]\nclass = Pregnancies'),
#  Text(334.79999999999995, 2582.0999999999995, 'X[6] <= 0.109\ngini = 0.444\nsamples = 6\nvalue = [2, 4]\nclass = Glucose'),
#  Text(279.0, 2310.2999999999997, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]\nclass = Glucose'),
#  Text(390.59999999999997, 2310.2999999999997, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Pregnancies'),
#  Text(558.0, 2582.0999999999995, 'X[6] <= 2.415\ngini = 0.24\nsamples = 86\nvalue = [74, 12]\nclass = Pregnancies'),
#  Text(502.2, 2310.2999999999997, 'X[6] <= 0.086\ngini = 0.225\nsamples = 85\nvalue = [74, 11]\nclass = Pregnancies'),
#  Text(390.59999999999997, 2038.4999999999998, 'X[5] <= 1.695\ngini = 0.135\nsamples = 55\nvalue = [51, 4]\nclass = Pregnancies'),
#  Text(334.79999999999995, 1766.6999999999998, 'X[4] <= -0.376\ngini = 0.105\nsamples = 54\nvalue = [51, 3]\nclass = Pregnancies'),
#  Text(279.0, 1494.8999999999996, 'X[4] <= -0.398\ngini = 0.266\nsamples = 19\nvalue = [16, 3]\nclass = Pregnancies'),
#  Text(223.2, 1223.1, 'X[1] <= -0.294\ngini = 0.198\nsamples = 18\nvalue = [16, 2]\nclass = Pregnancies'),
#  Text(167.39999999999998, 951.2999999999997, 'gini = 0.0\nsamples = 13\nvalue = [13, 0]\nclass = Pregnancies'),
#  Text(279.0, 951.2999999999997, 'X[5] <= 0.318\ngini = 0.48\nsamples = 5\nvalue = [3, 2]\nclass = Pregnancies'),
#  Text(223.2, 679.4999999999995, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Glucose'),
#  Text(334.79999999999995, 679.4999999999995, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = Pregnancies'),
#  Text(334.79999999999995, 1223.1, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Glucose'),
#  Text(390.59999999999997, 1494.8999999999996, 'gini = 0.0\nsamples = 35\nvalue = [35, 0]\nclass = Pregnancies'),
#  Text(446.4, 1766.6999999999998, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Glucose'),
#  Text(613.8, 2038.4999999999998, 'X[2] <= -0.005\ngini = 0.358\nsamples = 30\nvalue = [23, 7]\nclass = Pregnancies'),
#  Text(558.0, 1766.6999999999998, 'X[1] <= -1.014\ngini = 0.492\nsamples = 16\nvalue = [9, 7]\nclass = Pregnancies'),
#  Text(502.2, 1494.8999999999996, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]\nclass = Pregnancies'),
#  Text(613.8, 1494.8999999999996, 'X[6] <= 1.317\ngini = 0.346\nsamples = 9\nvalue = [2, 7]\nclass = Glucose'),
#  Text(558.0, 1223.1, 'X[0] <= -0.993\ngini = 0.219\nsamples = 8\nvalue = [1, 7]\nclass = Glucose'),
#  Text(502.2, 951.2999999999997, 'X[5] <= 0.597\ngini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = Glucose'),
#  Text(446.4, 679.4999999999995, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Glucose'),
#  Text(558.0, 679.4999999999995, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Pregnancies'),
#  Text(613.8, 951.2999999999997, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]\nclass = Glucose'),
#  Text(669.5999999999999, 1223.1, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Pregnancies'),
#  Text(669.5999999999999, 1766.6999999999998, 'gini = 0.0\nsamples = 14\nvalue = [14, 0]\nclass = Pregnancies'),
#  Text(613.8, 2310.2999999999997, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Glucose'),
#  Text(1290.375, 3125.7, 'X[5] <= -0.716\ngini = 0.43\nsamples = 150\nvalue = [103, 47]\nclass = Pregnancies'),
#  Text(1234.575, 2853.8999999999996, 'gini = 0.0\nsamples = 29\nvalue = [29, 0]\nclass = Pregnancies'),
#  Text(1346.175, 2853.8999999999996, 'X[1] <= -0.67\ngini = 0.475\nsamples = 121\nvalue = [74, 47]\nclass = Pregnancies'),
#  Text(892.8, 2582.0999999999995, 'X[1] <= -2.892\ngini = 0.337\nsamples = 42\nvalue = [33, 9]\nclass = Pregnancies'),
#  Text(837.0, 2310.2999999999997, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Glucose'),
#  Text(948.5999999999999, 2310.2999999999997, 'X[7] <= 0.788\ngini = 0.289\nsamples = 40\nvalue = [33, 7]\nclass = Pregnancies'),
#  Text(837.0, 2038.4999999999998, 'X[6] <= 2.078\ngini = 0.137\nsamples = 27\nvalue = [25, 2]\nclass = Pregnancies'),
#  Text(781.1999999999999, 1766.6999999999998, 'X[1] <= -0.842\ngini = 0.074\nsamples = 26\nvalue = [25, 1]\nclass = Pregnancies'),
#  Text(725.4, 1494.8999999999996, 'gini = 0.0\nsamples = 22\nvalue = [22, 0]\nclass = Pregnancies'),
#  Text(837.0, 1494.8999999999996, 'X[7] <= -0.148\ngini = 0.375\nsamples = 4\nvalue = [3, 1]\nclass = Pregnancies'),
#  Text(781.1999999999999, 1223.1, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Glucose'),
#  Text(892.8, 1223.1, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = Pregnancies'),
#  Text(892.8, 1766.6999999999998, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Glucose'),
#  Text(1060.2, 2038.4999999999998, 'X[5] <= -0.145\ngini = 0.473\nsamples = 13\nvalue = [8, 5]\nclass = Pregnancies'),
#  Text(1004.4, 1766.6999999999998, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Glucose'),
#  Text(1116.0, 1766.6999999999998, 'X[3] <= 0.06\ngini = 0.397\nsamples = 11\nvalue = [8, 3]\nclass = Pregnancies'),
#  Text(1060.2, 1494.8999999999996, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]\nclass = Pregnancies'),
#  Text(1171.8, 1494.8999999999996, 'X[2] <= 0.305\ngini = 0.5\nsamples = 6\nvalue = [3, 3]\nclass = Pregnancies'),
#  Text(1116.0, 1223.1, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = Pregnancies'),
#  Text(1227.6, 1223.1, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = Glucose'),
#  Text(1799.55, 2582.0999999999995, 'X[5] <= -0.564\ngini = 0.499\nsamples = 79\nvalue = [41, 38]\nclass = Pregnancies'),
#  Text(1743.75, 2310.2999999999997, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]\nclass = Glucose'),
#  Text(1855.35, 2310.2999999999997, 'X[6] <= -0.885\ngini = 0.494\nsamples = 74\nvalue = [41, 33]\nclass = Pregnancies'),
#  Text(1799.55, 2038.4999999999998, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]\nclass = Pregnancies'),
#  Text(1911.1499999999999, 2038.4999999999998, 'X[0] <= 0.788\ngini = 0.5\nsamples = 66\nvalue = [33, 33]\nclass = Pregnancies'),
#  Text(1590.3, 1766.6999999999998, 'X[0] <= -0.696\ngini = 0.483\nsamples = 44\nvalue = [26, 18]\nclass = Pregnancies'),
#  Text(1395.0, 1494.8999999999996, 'X[6] <= 1.273\ngini = 0.475\nsamples = 18\nvalue = [7, 11]\nclass = Glucose'),
#  Text(1339.1999999999998, 1223.1, 'X[6] <= -0.821\ngini = 0.391\nsamples = 15\nvalue = [4, 11]\nclass = Glucose'),
#  Text(1283.3999999999999, 951.2999999999997, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Pregnancies'),
#  Text(1395.0, 951.2999999999997, 'X[1] <= -0.623\ngini = 0.26\nsamples = 13\nvalue = [2, 11]\nclass = Glucose'),
#  Text(1339.1999999999998, 679.4999999999995, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Pregnancies'),
#  Text(1450.8, 679.4999999999995, 'X[2] <= 1.184\ngini = 0.153\nsamples = 12\nvalue = [1, 11]\nclass = Glucose'),
#  Text(1395.0, 407.6999999999998, 'gini = 0.0\nsamples = 11\nvalue = [0, 11]\nclass = Glucose'),
#  Text(1506.6, 407.6999999999998, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Pregnancies'),
#  Text(1450.8, 1223.1, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = Pregnancies'),
#  Text(1785.6, 1494.8999999999996, 'X[7] <= 0.107\ngini = 0.393\nsamples = 26\nvalue = [19, 7]\nclass = Pregnancies'),
#  Text(1674.0, 1223.1, 'X[2] <= -0.316\ngini = 0.133\nsamples = 14\nvalue = [13, 1]\nclass = Pregnancies'),
#  Text(1618.1999999999998, 951.2999999999997, 'X[6] <= -0.01\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Pregnancies'),
#  Text(1562.3999999999999, 679.4999999999995, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Glucose'),
#  Text(1674.0, 679.4999999999995, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Pregnancies'),
#  Text(1729.8, 951.2999999999997, 'gini = 0.0\nsamples = 12\nvalue = [12, 0]\nclass = Pregnancies'),
#  Text(1897.1999999999998, 1223.1, 'X[2] <= 0.279\ngini = 0.5\nsamples = 12\nvalue = [6, 6]\nclass = Pregnancies'),
#  Text(1841.3999999999999, 951.2999999999997, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]\nclass = Glucose'),
#  Text(1953.0, 951.2999999999997, 'X[5] <= 0.083\ngini = 0.375\nsamples = 8\nvalue = [6, 2]\nclass = Pregnancies'),
#  Text(1897.1999999999998, 679.4999999999995, 'X[7] <= 1.851\ngini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = Glucose'),
#  Text(1841.3999999999999, 407.6999999999998, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Glucose'),
#  Text(1953.0, 407.6999999999998, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Pregnancies'),
#  Text(2008.8, 679.4999999999995, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]\nclass = Pregnancies'),
#  Text(2232.0, 1766.6999999999998, 'X[7] <= 0.49\ngini = 0.434\nsamples = 22\nvalue = [7, 15]\nclass = Glucose'),
#  Text(2176.2, 1494.8999999999996, 'gini = 0.0\nsamples = 8\nvalue = [0, 8]\nclass = Glucose'),
#  Text(2287.7999999999997, 1494.8999999999996, 'X[6] <= 0.346\ngini = 0.5\nsamples = 14\nvalue = [7, 7]\nclass = Pregnancies'),
#  Text(2232.0, 1223.1, 'X[1] <= -0.372\ngini = 0.42\nsamples = 10\nvalue = [7, 3]\nclass = Pregnancies'),
#  Text(2176.2, 951.2999999999997, 'X[5] <= -0.101\ngini = 0.5\nsamples = 6\nvalue = [3, 3]\nclass = Pregnancies'),
#  Text(2120.4, 679.4999999999995, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Pregnancies'),
#  Text(2232.0, 679.4999999999995, 'X[2] <= 0.356\ngini = 0.48\nsamples = 5\nvalue = [2, 3]\nclass = Glucose'),
#  Text(2176.2, 407.6999999999998, 'X[1] <= -0.435\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = Pregnancies'),
#  Text(2120.4, 135.89999999999964, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Pregnancies'),
#  Text(2232.0, 135.89999999999964, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Glucose'),
#  Text(2287.7999999999997, 407.6999999999998, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Glucose'),
#  Text(2287.7999999999997, 951.2999999999997, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = Pregnancies'),
#  Text(2343.6, 1223.1, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]\nclass = Glucose'),
#  Text(3750.8062499999996, 3397.5, 'X[5] <= -0.247\ngini = 0.482\nsamples = 262\nvalue = [106, 156]\nclass = Glucose'),
#  Text(2803.95, 3125.7, 'X[7] <= -0.616\ngini = 0.438\nsamples = 74\nvalue = [50, 24]\nclass = Pregnancies'),
#  Text(2748.1499999999996, 2853.8999999999996, 'gini = 0.0\nsamples = 19\nvalue = [19, 0]\nclass = Pregnancies'),
#  Text(2859.75, 2853.8999999999996, 'X[7] <= 2.319\ngini = 0.492\nsamples = 55\nvalue = [31, 24]\nclass = Pregnancies'),
#  Text(2803.95, 2582.0999999999995, 'X[1] <= 0.958\ngini = 0.5\nsamples = 47\nvalue = [23, 24]\nclass = Glucose'),
#  Text(2594.7, 2310.2999999999997, 'X[1] <= 0.144\ngini = 0.469\nsamples = 32\nvalue = [20, 12]\nclass = Pregnancies'),
#  Text(2399.4, 2038.4999999999998, 'X[3] <= 0.405\ngini = 0.375\nsamples = 8\nvalue = [2, 6]\nclass = Glucose'),
#  Text(2343.6, 1766.6999999999998, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]\nclass = Glucose'),
#  Text(2455.2, 1766.6999999999998, 'X[6] <= 0.129\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = Pregnancies'),
#  Text(2399.4, 1494.8999999999996, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Pregnancies'),
#  Text(2511.0, 1494.8999999999996, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Glucose'),
#  Text(2790.0, 2038.4999999999998, 'X[2] <= 0.201\ngini = 0.375\nsamples = 24\nvalue = [18, 6]\nclass = Pregnancies'),
#  Text(2678.3999999999996, 1766.6999999999998, 'X[2] <= -0.238\ngini = 0.5\nsamples = 8\nvalue = [4, 4]\nclass = Pregnancies'),
#  Text(2622.6, 1494.8999999999996, 'X[2] <= -2.125\ngini = 0.32\nsamples = 5\nvalue = [4, 1]\nclass = Pregnancies'),
#  Text(2566.7999999999997, 1223.1, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Glucose'),
#  Text(2678.3999999999996, 1223.1, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = Pregnancies'),
#  Text(2734.2, 1494.8999999999996, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = Glucose'),
#  Text(2901.6, 1766.6999999999998, 'X[5] <= -0.507\ngini = 0.219\nsamples = 16\nvalue = [14, 2]\nclass = Pregnancies'),
#  Text(2845.7999999999997, 1494.8999999999996, 'gini = 0.0\nsamples = 9\nvalue = [9, 0]\nclass = Pregnancies'),
#  Text(2957.3999999999996, 1494.8999999999996, 'X[5] <= -0.31\ngini = 0.408\nsamples = 7\nvalue = [5, 2]\nclass = Pregnancies'),
#  Text(2901.6, 1223.1, 'X[7] <= -0.233\ngini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = Glucose'),
#  Text(2845.7999999999997, 951.2999999999997, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Pregnancies'),
#  Text(2957.3999999999996, 951.2999999999997, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Glucose'),
#  Text(3013.2, 1223.1, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = Pregnancies'),
#  Text(3013.2, 2310.2999999999997, 'X[5] <= -0.621\ngini = 0.32\nsamples = 15\nvalue = [3, 12]\nclass = Glucose'),
#  Text(2957.3999999999996, 2038.4999999999998, 'gini = 0.0\nsamples = 8\nvalue = [0, 8]\nclass = Glucose'),
#  Text(3069.0, 2038.4999999999998, 'X[7] <= 0.277\ngini = 0.49\nsamples = 7\nvalue = [3, 4]\nclass = Glucose'),
#  Text(3013.2, 1766.6999999999998, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = Glucose'),
#  Text(3124.7999999999997, 1766.6999999999998, 'X[6] <= 1.433\ngini = 0.375\nsamples = 4\nvalue = [3, 1]\nclass = Pregnancies'),
#  Text(3069.0, 1494.8999999999996, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = Pregnancies'),
#  Text(3180.6, 1494.8999999999996, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Glucose'),
#  Text(2915.5499999999997, 2582.0999999999995, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]\nclass = Pregnancies'),
#  Text(4697.662499999999, 3125.7, 'X[1] <= 1.146\ngini = 0.418\nsamples = 188\nvalue = [56, 132]\nclass = Glucose'),
#  Text(4066.4249999999997, 2853.8999999999996, 'X[7] <= -0.403\ngini = 0.482\nsamples = 116\nvalue = [47, 69]\nclass = Glucose'),
#  Text(3627.0, 2582.0999999999995, 'X[2] <= 0.201\ngini = 0.49\nsamples = 42\nvalue = [24, 18]\nclass = Pregnancies'),
#  Text(3403.7999999999997, 2310.2999999999997, 'X[6] <= -0.863\ngini = 0.463\nsamples = 22\nvalue = [8, 14]\nclass = Glucose'),
#  Text(3348.0, 2038.4999999999998, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = Pregnancies'),
#  Text(3459.6, 2038.4999999999998, 'X[1] <= 0.817\ngini = 0.388\nsamples = 19\nvalue = [5, 14]\nclass = Glucose'),
#  Text(3348.0, 1766.6999999999998, 'X[4] <= 2.476\ngini = 0.231\nsamples = 15\nvalue = [2, 13]\nclass = Glucose'),
#  Text(3292.2, 1494.8999999999996, 'X[0] <= -0.102\ngini = 0.133\nsamples = 14\nvalue = [1, 13]\nclass = Glucose'),
#  Text(3236.3999999999996, 1223.1, 'gini = 0.0\nsamples = 11\nvalue = [0, 11]\nclass = Glucose'),
#  Text(3348.0, 1223.1, 'X[5] <= 0.204\ngini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = Glucose'),
#  Text(3292.2, 951.2999999999997, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Glucose'),
#  Text(3403.7999999999997, 951.2999999999997, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Pregnancies'),
#  Text(3403.7999999999997, 1494.8999999999996, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Pregnancies'),
#  Text(3571.2, 1766.6999999999998, 'X[2] <= -0.626\ngini = 0.375\nsamples = 4\nvalue = [3, 1]\nclass = Pregnancies'),
#  Text(3515.3999999999996, 1494.8999999999996, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Glucose'),
#  Text(3627.0, 1494.8999999999996, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = Pregnancies'),
#  Text(3850.2, 2310.2999999999997, 'X[2] <= 1.029\ngini = 0.32\nsamples = 20\nvalue = [16, 4]\nclass = Pregnancies'),
#  Text(3738.6, 2038.4999999999998, 'X[0] <= 0.194\ngini = 0.117\nsamples = 16\nvalue = [15, 1]\nclass = Pregnancies'),
#  Text(3682.7999999999997, 1766.6999999999998, 'gini = 0.0\nsamples = 14\nvalue = [14, 0]\nclass = Pregnancies'),
#  Text(3794.3999999999996, 1766.6999999999998, 'X[3] <= 1.095\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Pregnancies'),
#  Text(3738.6, 1494.8999999999996, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Glucose'),
#  Text(3850.2, 1494.8999999999996, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Pregnancies'),
#  Text(3961.7999999999997, 2038.4999999999998, 'X[6] <= -0.515\ngini = 0.375\nsamples = 4\nvalue = [1, 3]\nclass = Glucose'),
#  Text(3906.0, 1766.6999999999998, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Pregnancies'),
#  Text(4017.6, 1766.6999999999998, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = Glucose'),
#  Text(4505.849999999999, 2582.0999999999995, 'X[6] <= -0.128\ngini = 0.428\nsamples = 74\nvalue = [23, 51]\nclass = Glucose'),
#  Text(4240.8, 2310.2999999999997, 'X[5] <= 1.721\ngini = 0.499\nsamples = 38\nvalue = [18, 20]\nclass = Glucose'),
#  Text(4185.0, 2038.4999999999998, 'X[0] <= -0.696\ngini = 0.496\nsamples = 33\nvalue = [18, 15]\nclass = Pregnancies'),
#  Text(4129.2, 1766.6999999999998, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = Glucose'),
#  Text(4240.8, 1766.6999999999998, 'X[5] <= 0.667\ngini = 0.48\nsamples = 30\nvalue = [18, 12]\nclass = Pregnancies'),
#  Text(4129.2, 1494.8999999999996, 'X[2] <= 1.029\ngini = 0.499\nsamples = 21\nvalue = [10, 11]\nclass = Glucose'),
#  Text(4073.3999999999996, 1223.1, 'X[4] <= 0.336\ngini = 0.499\nsamples = 19\nvalue = [10, 9]\nclass = Pregnancies'),
#  Text(3933.8999999999996, 951.2999999999997, 'X[1] <= 0.504\ngini = 0.473\nsamples = 13\nvalue = [5, 8]\nclass = Glucose'),
#  Text(3822.2999999999997, 679.4999999999995, 'X[7] <= 0.958\ngini = 0.219\nsamples = 8\nvalue = [1, 7]\nclass = Glucose'),
#  Text(3766.5, 407.6999999999998, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]\nclass = Glucose'),
#  Text(3878.1, 407.6999999999998, 'X[5] <= 0.28\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Pregnancies'),
#  Text(3822.2999999999997, 135.89999999999964, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Glucose'),
#  Text(3933.8999999999996, 135.89999999999964, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Pregnancies'),
#  Text(4045.5, 679.4999999999995, 'X[7] <= 2.915\ngini = 0.32\nsamples = 5\nvalue = [4, 1]\nclass = Pregnancies'),
#  Text(3989.7, 407.6999999999998, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = Pregnancies'),
#  Text(4101.3, 407.6999999999998, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Glucose'),
#  Text(4212.9, 951.2999999999997, 'X[5] <= -0.043\ngini = 0.278\nsamples = 6\nvalue = [5, 1]\nclass = Pregnancies'),
#  Text(4157.099999999999, 679.4999999999995, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Glucose'),
#  Text(4268.7, 679.4999999999995, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]\nclass = Pregnancies'),
#  Text(4185.0, 1223.1, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Glucose'),
#  Text(4352.4, 1494.8999999999996, 'X[1] <= 0.801\ngini = 0.198\nsamples = 9\nvalue = [8, 1]\nclass = Pregnancies'),
#  Text(4296.599999999999, 1223.1, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]\nclass = Pregnancies'),
#  Text(4408.2, 1223.1, 'X[3] <= -0.19\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Pregnancies'),
#  Text(4352.4, 951.2999999999997, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Glucose'),
#  Text(4464.0, 951.2999999999997, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Pregnancies'),
#  Text(4296.599999999999, 2038.4999999999998, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]\nclass = Glucose'),
#  Text(4770.9, 2310.2999999999997, 'X[4] <= 2.203\ngini = 0.239\nsamples = 36\nvalue = [5, 31]\nclass = Glucose'),
#  Text(4631.4, 2038.4999999999998, 'X[0] <= -0.993\ngini = 0.165\nsamples = 33\nvalue = [3, 30]\nclass = Glucose'),
#  Text(4519.8, 1766.6999999999998, 'X[2] <= -0.471\ngini = 0.48\nsamples = 5\nvalue = [2, 3]\nclass = Glucose'),
#  Text(4464.0, 1494.8999999999996, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Glucose'),
#  Text(4575.599999999999, 1494.8999999999996, 'X[2] <= 0.822\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = Pregnancies'),
#  Text(4519.8, 1223.1, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Pregnancies'),
#  Text(4631.4, 1223.1, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Glucose'),
#  Text(4743.0, 1766.6999999999998, 'X[5] <= 1.023\ngini = 0.069\nsamples = 28\nvalue = [1, 27]\nclass = Glucose'),
#  Text(4687.2, 1494.8999999999996, 'gini = 0.0\nsamples = 22\nvalue = [0, 22]\nclass = Glucose'),
#  Text(4798.8, 1494.8999999999996, 'X[5] <= 1.105\ngini = 0.278\nsamples = 6\nvalue = [1, 5]\nclass = Glucose'),
#  Text(4743.0, 1223.1, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Pregnancies'),
#  Text(4854.599999999999, 1223.1, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]\nclass = Glucose'),
#  Text(4910.4, 2038.4999999999998, 'X[5] <= 0.299\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = Pregnancies'),
#  Text(4854.599999999999, 1766.6999999999998, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Glucose'),
#  Text(4966.2, 1766.6999999999998, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Pregnancies'),
#  Text(5328.9, 2853.8999999999996, 'X[4] <= 4.473\ngini = 0.219\nsamples = 72\nvalue = [9, 63]\nclass = Glucose'),
#  Text(5189.4, 2582.0999999999995, 'X[6] <= -0.499\ngini = 0.182\nsamples = 69\nvalue = [7, 62]\nclass = Glucose'),
#  Text(5077.8, 2310.2999999999997, 'X[5] <= -0.075\ngini = 0.401\nsamples = 18\nvalue = [5, 13]\nclass = Glucose'),
#  Text(5022.0, 2038.4999999999998, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Pregnancies'),
#  Text(5133.599999999999, 2038.4999999999998, 'X[1] <= 1.834\ngini = 0.305\nsamples = 16\nvalue = [3, 13]\nclass = Glucose'),
#  Text(5077.8, 1766.6999999999998, 'X[1] <= 1.756\ngini = 0.42\nsamples = 10\nvalue = [3, 7]\nclass = Glucose'),
#  Text(5022.0, 1494.8999999999996, 'X[0] <= -0.993\ngini = 0.219\nsamples = 8\nvalue = [1, 7]\nclass = Glucose'),
#  Text(4966.2, 1223.1, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Pregnancies'),
#  Text(5077.8, 1223.1, 'gini = 0.0\nsamples = 7\nvalue = [0, 7]\nclass = Glucose'),
#  Text(5133.599999999999, 1494.8999999999996, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Pregnancies'),
#  Text(5189.4, 1766.6999999999998, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]\nclass = Glucose'),
#  Text(5301.0, 2310.2999999999997, 'X[7] <= 1.256\ngini = 0.075\nsamples = 51\nvalue = [2, 49]\nclass = Glucose'),
#  Text(5245.2, 2038.4999999999998, 'gini = 0.0\nsamples = 42\nvalue = [0, 42]\nclass = Glucose'),
#  Text(5356.799999999999, 2038.4999999999998, 'X[6] <= 1.692\ngini = 0.346\nsamples = 9\nvalue = [2, 7]\nclass = Glucose'),
#  Text(5301.0, 1766.6999999999998, 'X[7] <= 1.469\ngini = 0.219\nsamples = 8\nvalue = [1, 7]\nclass = Glucose'),
#  Text(5245.2, 1494.8999999999996, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Pregnancies'),
#  Text(5356.799999999999, 1494.8999999999996, 'gini = 0.0\nsamples = 7\nvalue = [0, 7]\nclass = Glucose'),
#  Text(5412.599999999999, 1766.6999999999998, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Pregnancies'),
#  Text(5468.4, 2582.0999999999995, 'X[6] <= -0.179\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = Pregnancies'),
#  Text(5412.599999999999, 2310.2999999999997, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Glucose'),
#  Text(5524.2, 2310.2999999999997, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Pregnancies')]

# %%
# find out probability
y_prob_tree=best_model.predict_proba(x_test)
y_prob_tree
# Out:
# array([[0.29787234, 0.70212766],
#        [0.91089109, 0.08910891],
#        [0.91089109, 0.08910891],
#        [0.67567568, 0.32432432],
#        [0.68666667, 0.31333333],
#        [0.91089109, 0.08910891],
#        [0.29787234, 0.70212766],
#        [0.29787234, 0.70212766],
#        [0.67567568, 0.32432432],
#        [0.68666667, 0.31333333],
#        [0.29787234, 0.70212766],
#        [0.29787234, 0.70212766],
#        [0.68666667, 0.31333333],
#        [0.91089109, 0.08910891],
#        [0.68666667, 0.31333333],
#        [0.68666667, 0.31333333],
#        [0.29787234, 0.70212766],
#        [0.91089109, 0.08910891],
#        [0.67567568, 0.32432432],
#        [0.68666667, 0.31333333],
#        [0.29787234, 0.70212766],
#        [0.91089109, 0.08910891],
#        [0.91089109, 0.08910891],
#        [0.68666667, 0.31333333],
#        [0.91089109, 0.08910891],
#        [0.29787234, 0.70212766],
#        [0.91089109, 0.08910891],
#        [0.29787234, 0.70212766],
#        [0.91089109, 0.08910891],
#        [0.68666667, 0.31333333],
#        [0.67567568, 0.32432432],
#        [0.91089109, 0.08910891],
#        [0.91089109, 0.08910891],
#        [0.91089109, 0.08910891],
#        [0.91089109, 0.08910891],
#        [0.29787234, 0.70212766],
#        [0.67567568, 0.32432432],
#        [0.91089109, 0.08910891],
#        [0.91089109, 0.08910891],
#        [0.29787234, 0.70212766],
#        [0.91089109, 0.08910891],
#        [0.91089109, 0.08910891],
#        [0.68666667, 0.31333333],
#        [0.29787234, 0.70212766],
#        [0.29787234, 0.70212766],
#        [0.91089109, 0.08910891],
#        [0.91089109, 0.08910891],
#        [0.67567568, 0.32432432],
#        [0.91089109, 0.08910891],
#        [0.29787234, 0.70212766],
#        [0.67567568, 0.32432432],
#        [0.91089109, 0.08910891],
#        [0.29787234, 0.70212766],
#        [0.29787234, 0.70212766],
#        [0.91089109, 0.08910891],
#        [0.91089109, 0.08910891],
#        [0.68666667, 0.31333333],
#        [0.91089109, 0.08910891],
#        [0.67567568, 0.32432432],
#        [0.68666667, 0.31333333],
#        [0.29787234, 0.70212766],
#        [0.29787234, 0.70212766],
#        [0.67567568, 0.32432432],
#        [0.29787234, 0.70212766],
#        [0.29787234, 0.70212766],
#        [0.67567568, 0.32432432],
#        [0.29787234, 0.70212766],
#        [0.68666667, 0.31333333],
#        [0.68666667, 0.31333333],
#        [0.68666667, 0.31333333],
#        [0.91089109, 0.08910891],
#        [0.68666667, 0.31333333],
#        [0.91089109, 0.08910891],
#        [0.29787234, 0.70212766],
#        [0.29787234, 0.70212766],
#        [0.29787234, 0.70212766],
#        [0.68666667, 0.31333333],
#        [0.67567568, 0.32432432],
#        [0.68666667, 0.31333333],
#        [0.68666667, 0.31333333],
#        [0.68666667, 0.31333333],
#        [0.29787234, 0.70212766],
#        [0.91089109, 0.08910891],
#        [0.91089109, 0.08910891],
#        [0.91089109, 0.08910891],
#        [0.68666667, 0.31333333],
#        [0.67567568, 0.32432432],
#        [0.68666667, 0.31333333],
#        [0.29787234, 0.70212766],
#        [0.91089109, 0.08910891],
#        [0.67567568, 0.32432432],
#        [0.67567568, 0.32432432],
#        [0.91089109, 0.08910891],
#        [0.91089109, 0.08910891],
#        [0.29787234, 0.70212766],
#        [0.91089109, 0.08910891],
#        [0.68666667, 0.31333333],
#        [0.29787234, 0.70212766],
#        [0.68666667, 0.31333333],
#        [0.68666667, 0.31333333],
#        [0.91089109, 0.08910891],
#        [0.91089109, 0.08910891],
#        [0.68666667, 0.31333333],
#        [0.91089109, 0.08910891],
#        [0.29787234, 0.70212766],
#        [0.68666667, 0.31333333],
#        [0.67567568, 0.32432432],
#        [0.29787234, 0.70212766],
#        [0.68666667, 0.31333333],
#        [0.67567568, 0.32432432],
#        [0.91089109, 0.08910891],
#        [0.68666667, 0.31333333],
#        [0.29787234, 0.70212766],
#        [0.29787234, 0.70212766],
#        [0.29787234, 0.70212766],
#        [0.29787234, 0.70212766],
#        [0.91089109, 0.08910891],
#        [0.67567568, 0.32432432],
#        [0.91089109, 0.08910891],
#        [0.68666667, 0.31333333],
#        [0.68666667, 0.31333333],
#        [0.68666667, 0.31333333],
#        [0.91089109, 0.08910891],
#        [0.68666667, 0.31333333],
#        [0.67567568, 0.32432432],
#        [0.91089109, 0.08910891],
#        [0.29787234, 0.70212766],
#        [0.68666667, 0.31333333],
#        [0.67567568, 0.32432432],
#        [0.67567568, 0.32432432],
#        [0.67567568, 0.32432432],
#        [0.91089109, 0.08910891],
#        [0.91089109, 0.08910891],
#        [0.29787234, 0.70212766],
#        [0.68666667, 0.31333333],
#        [0.68666667, 0.31333333],
#        [0.68666667, 0.31333333],
#        [0.68666667, 0.31333333],
#        [0.67567568, 0.32432432],
#        [0.91089109, 0.08910891],
#        [0.91089109, 0.08910891],
#        [0.29787234, 0.70212766],
#        [0.91089109, 0.08910891],
#        [0.68666667, 0.31333333],
#        [0.68666667, 0.31333333],
#        [0.91089109, 0.08910891],
#        [0.68666667, 0.31333333],
#        [0.68666667, 0.31333333],
#        [0.91089109, 0.08910891],
#        [0.68666667, 0.31333333],
#        [0.91089109, 0.08910891],
#        [0.29787234, 0.70212766],
#        [0.91089109, 0.08910891],
#        [0.91089109, 0.08910891]])

# %%
fpr,tpr,threshold=roc_curve(y_test,y_prob_tree[:,1])

# %%
import pickle

# %%
pickle.dump(train_data,open('train_data.pickle','wb'))

# %%
five=x_test.head()

# %%
pickle.dump(five,open('five.pickle','wb'))

# %%
y_test.head()
# Out:
#      Outcome
# 661        1
# 122        0
# 113        0
# 14         1
# 529        0

# %% [markdown]
# # Apply KNN on diabities

# %%
sns.countplot(x='Outcome',data=df)
# Out:
# <AxesSubplot:xlabel='Outcome', ylabel='count'>

# %%
# by using the scaling 
from sklearn.preprocessing import MinMaxScaler,StandardScaler

# %%
# normal_scale=MinMaxScaler()
# x_scaled=normal_scale.fit_transform(x)
# x=pd.DataFrame(x_scaled,columns=x.columns)
# x

# %%
std_scale=StandardScaler()
x_scaled=std_scale.fit_transform(x)
x=pd.DataFrame(x_scaled,columns=x.columns)
x
# Out:
#      Pregnancies   Glucose  BloodPressure  SkinThickness   Insulin       BMI  \
# 0       0.639947  0.848324       0.149641       0.907270 -0.692891  0.204013
# 1      -0.844885 -1.123396      -0.160546       0.530902 -0.692891 -0.684422
# 2       1.233880  1.943724      -0.263941      -1.288212 -0.692891 -1.103255
# 3      -0.844885 -0.998208      -0.160546       0.154533  0.123302 -0.494043
# 4      -1.141852  0.504055      -1.504687       0.907270  0.765836  1.409746
# ..           ...       ...            ...            ...       ...       ...
# 763     1.827813 -0.622642       0.356432       1.722735  0.870031  0.115169
# 764    -0.547919  0.034598       0.046245       0.405445 -0.692891  0.610154
# 765     0.342981  0.003301       0.149641       0.154533  0.279594 -0.735190
# 766    -0.844885  0.159787      -0.470732      -1.288212 -0.692891 -0.240205
# 767    -0.844885 -0.873019       0.046245       0.656358 -0.692891 -0.202129
#
#      DiabetesPedigreeFunction       Age
# 0                    0.468492  1.425995
# 1                   -0.365061 -0.190672
# 2                    0.604397 -0.105584
# 3                   -0.920763 -1.041549
# 4                    5.484909 -0.020496
# ..                        ...       ...
# 763                 -0.908682  2.532136
# 764                 -0.398282 -0.531023
# 765                 -0.685193 -0.275760
# 766                 -0.371101  1.170732
# 767                 -0.473785 -0.871374
#
# [768 rows x 8 columns]

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn_model=KNeighborsClassifier()
knn_model.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
y_test1_pred=knn_model.predict(x_test1)

# %%
confusion_matrix(y_test1,y_test1_pred)
# Out:
# array([[94, 13],
#        [17, 30]], dtype=int64)

# %%
cls_knn=classification_report(y_test1,y_test1_pred)
print(cls_knn)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.88      0.86       107
#            1       0.70      0.64      0.67        47
#
#     accuracy                           0.81       154
#    macro avg       0.77      0.76      0.76       154
# weighted avg       0.80      0.81      0.80       154

# %%
accuracy_score(y_test1,y_test1_pred)
# Out:
# 0.8051948051948052

# %% [markdown]
# # cheak accuracy of on train data

# %%
y_train1_pred = knn_model.predict(x_train1)
accuracy_score(y_train1,y_train1_pred)
# Out:
# 0.8127035830618893

# %%
# check the accuracy by using hyperparameter
n_neighbors = list(range(5,50))
p = [1,2]
hyperparameter =dict(n_neighbors=n_neighbors,p = p)
new_model=KNeighborsClassifier()
gscv=GridSearchCV(new_model,hyperparameter,cv=5)
# rscv=RandomizedSearchCV(new_model,hyperparameter,cv=5)

knn_new_model =gscv.fit(x_train1,y_train1)

# %%
y_best_test1_pred=knn_new_model.predict(x_test1)

# %%
accuracy_score(y_test1,y_best_test1_pred)
# Out:
# 0.7792207792207793

# %%
knn_new_model.best_estimator_
# Out:
# KNeighborsClassifier(n_neighbors=41)

# %%
# findout probability on best accuracy model
y_prob_knn =knn_model.predict_proba(x_test1)
y_prob_knn
# Out:
# array([[0. , 1. ],
#        [1. , 0. ],
#        [0.8, 0.2],
#        [0.4, 0.6],
#        [1. , 0. ],
#        [1. , 0. ],
#        [0.4, 0.6],
#        [0.2, 0.8],
#        [0.4, 0.6],
#        [1. , 0. ],
#        [0.4, 0.6],
#        [0.4, 0.6],
#        [0.6, 0.4],
#        [0.8, 0.2],
#        [0.8, 0.2],
#        [0.8, 0.2],
#        [0.2, 0.8],
#        [1. , 0. ],
#        [0.6, 0.4],
#        [0.8, 0.2],
#        [0.8, 0.2],
#        [1. , 0. ],
#        [1. , 0. ],
#        [0.8, 0.2],
#        [1. , 0. ],
#        [0.6, 0.4],
#        [1. , 0. ],
#        [0. , 1. ],
#        [1. , 0. ],
#        [0.6, 0.4],
#        [0.4, 0.6],
#        [1. , 0. ],
#        [1. , 0. ],
#        [0.2, 0.8],
#        [1. , 0. ],
#        [0.4, 0.6],
#        [0.8, 0.2],
#        [1. , 0. ],
#        [0.6, 0.4],
#        [0.4, 0.6],
#        [0.6, 0.4],
#        [1. , 0. ],
#        [0.6, 0.4],
#        [0.4, 0.6],
#        [0.4, 0.6],
#        [1. , 0. ],
#        [1. , 0. ],
#        [0.8, 0.2],
#        [0.4, 0.6],
#        [1. , 0. ],
#        [0.6, 0.4],
#        [1. , 0. ],
#        [0.2, 0.8],
#        [0.4, 0.6],
#        [1. , 0. ],
#        [1. , 0. ],
#        [1. , 0. ],
#        [0.4, 0.6],
#        [1. , 0. ],
#        [1. , 0. ],
#        [0.2, 0.8],
#        [0.6, 0.4],
#        [1. , 0. ],
#        [0.2, 0.8],
#        [0.4, 0.6],
#        [0.2, 0.8],
#        [0.4, 0.6],
#        [1. , 0. ],
#        [0.4, 0.6],
#        [0.6, 0.4],
#        [1. , 0. ],
#        [0.6, 0.4],
#        [1. , 0. ],
#        [0.4, 0.6],
#        [0.2, 0.8],
#        [0.8, 0.2],
#        [0.8, 0.2],
#        [0.6, 0.4],
#        [1. , 0. ],
#        [0.8, 0.2],
#        [0.6, 0.4],
#        [0.8, 0.2],
#        [0.4, 0.6],
#        [1. , 0. ],
#        [1. , 0. ],
#        [0.8, 0.2],
#        [1. , 0. ],
#        [0.8, 0.2],
#        [0.2, 0.8],
#        [1. , 0. ],
#        [0.6, 0.4],
#        [0.8, 0.2],
#        [0.8, 0.2],
#        [1. , 0. ],
#        [0.4, 0.6],
#        [1. , 0. ],
#        [0.8, 0.2],
#        [0.6, 0.4],
#        [0.4, 0.6],
#        [0.4, 0.6],
#        [0.6, 0.4],
#        [0.8, 0.2],
#        [0.8, 0.2],
#        [1. , 0. ],
#        [0.8, 0.2],
#        [0.6, 0.4],
#        [1. , 0. ],
#        [0.8, 0.2],
#        [1. , 0. ],
#        [0.4, 0.6],
#        [1. , 0. ],
#        [0.8, 0.2],
#        [0.2, 0.8],
#        [0.2, 0.8],
#        [0.4, 0.6],
#        [0.4, 0.6],
#        [1. , 0. ],
#        [0.6, 0.4],
#        [1. , 0. ],
#        [0. , 1. ],
#        [1. , 0. ],
#        [0.4, 0.6],
#        [1. , 0. ],
#        [1. , 0. ],
#        [0.8, 0.2],
#        [1. , 0. ],
#        [0.6, 0.4],
#        [1. , 0. ],
#        [0.4, 0.6],
#        [1. , 0. ],
#        [0.6, 0.4],
#        [1. , 0. ],
#        [1. , 0. ],
#        [0.6, 0.4],
#        [0.8, 0.2],
#        [0.6, 0.4],
#        [1. , 0. ],
#        [1. , 0. ],
#        [0.2, 0.8],
#        [1. , 0. ],
#        [1. , 0. ],
#        [0.2, 0.8],
#        [1. , 0. ],
#        [0.8, 0.2],
#        [0. , 1. ],
#        [1. , 0. ],
#        [0.8, 0.2],
#        [0.8, 0.2],
#        [0.8, 0.2],
#        [0.8, 0.2],
#        [1. , 0. ],
#        [0.8, 0.2],
#        [1. , 0. ],
#        [0.6, 0.4]])

# %%
fpr1,tpr1,threshold1=roc_curve(y_test1,y_prob_knn[:,1])

# %% [markdown]
# # apply Logistic on diabetes

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]

# %%
x1=df.drop(['Outcome'],axis=1)
y1=df[['Outcome']]

# %%
x_train2, x_test2, y_train2, y_test2 = train_test_split(x1,y1,test_size=0.2,random_state=0)

# %%
from sklearn.linear_model import LogisticRegression

# %%
logistic_model=LogisticRegression()
logistic_model.fit(x_train2,y_train2)
# Out:
# LogisticRegression()

# %%
y_pred_log=logistic_model.predict(x_test2)

# %%
confusion_matrix(y_test2,y_pred_log)
# Out:
# array([[98,  9],
#        [18, 29]], dtype=int64)

# %%
cls_log = classification_report(y_test2,y_pred_log)
print(cls_log)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.92      0.88       107
#            1       0.76      0.62      0.68        47
#
#     accuracy                           0.82       154
#    macro avg       0.80      0.77      0.78       154
# weighted avg       0.82      0.82      0.82       154

# %%
accuracy_score(y_test2,y_pred_log)
# Out:
# 0.8246753246753247

# %%
# to check accuracy on train data
y_train_pred_log=logistic_model.predict(x_train2)
accuracy_score(y_train2,y_train_pred_log)
# Out:
# 0.7719869706840391

# %% [markdown]
# # Hyper parameter Tunning

# %%
random_state=list(range(1,100))
max_iter = list(range(100,200))
hyperparameter1=dict(random_state=random_state,max_iter=max_iter)

# %%
new_=LogisticRegression()
# gscv1=GridSearchCV(new_,hyperparameter1,cv=2)
rscv1=RandomizedSearchCV(new_ ,hyperparameter1, cv=5)
new_logistic_model=rscv1.fit(x_train2,y_train2)

# %%
new_logistic_model.best_estimator_
# Out:
# LogisticRegression(max_iter=109, random_state=26)

# %%
y_best_pred_log1=new_logistic_model.predict(x_test2)

# %%
accuracy_score(y_test2,y_best_pred_log1)
# Out:
# 0.8246753246753247

# %%
y_pred_train_log=new_logistic_model.predict(x_train2)

# %%
accuracy_score(y_train2,y_pred_train_log)
# Out:
# 0.7703583061889251

# %%
# to find out the probability
y_pred_prob_log=logistic_model.predict_proba(x_test2)
y_pred_prob_log
# Out:
# array([[0.03700834, 0.96299166],
#        [0.82926704, 0.17073296],
#        [0.89823174, 0.10176826],
#        [0.37916144, 0.62083856],
#        [0.87082399, 0.12917601],
#        [0.96042464, 0.03957536],
#        [0.25698616, 0.74301384],
#        [0.15978235, 0.84021765],
#        [0.61119709, 0.38880291],
#        [0.65665428, 0.34334572],
#        [0.42463074, 0.57536926],
#        [0.04231811, 0.95768189],
#        [0.72576234, 0.27423766],
#        [0.82206747, 0.17793253],
#        [0.8811662 , 0.1188338 ],
#        [0.83673593, 0.16326407],
#        [0.13817879, 0.86182121],
#        [0.97119689, 0.02880311],
#        [0.60433673, 0.39566327],
#        [0.74267843, 0.25732157],
#        [0.33503602, 0.66496398],
#        [0.54839769, 0.45160231],
#        [0.76704652, 0.23295348],
#        [0.93918966, 0.06081034],
#        [0.94671699, 0.05328301],
#        [0.61985565, 0.38014435],
#        [0.95171176, 0.04828824],
#        [0.09369145, 0.90630855],
#        [0.88159263, 0.11840737],
#        [0.84861473, 0.15138527],
#        [0.55832157, 0.44167843],
#        [0.74025961, 0.25974039],
#        [0.90260658, 0.09739342],
#        [0.53913239, 0.46086761],
#        [0.89228333, 0.10771667],
#        [0.27390592, 0.72609408],
#        [0.55772268, 0.44227732],
#        [0.90943831, 0.09056169],
#        [0.65498767, 0.34501233],
#        [0.24054801, 0.75945199],
#        [0.70158824, 0.29841176],
#        [0.76161643, 0.23838357],
#        [0.83757347, 0.16242653],
#        [0.15858284, 0.84141716],
#        [0.27879899, 0.72120101],
#        [0.99109548, 0.00890452],
#        [0.9102886 , 0.0897114 ],
#        [0.79211679, 0.20788321],
#        [0.64159289, 0.35840711],
#        [0.67989845, 0.32010155],
#        [0.5836728 , 0.4163272 ],
#        [0.7992984 , 0.2007016 ],
#        [0.12823913, 0.87176087],
#        [0.51237562, 0.48762438],
#        [0.85870641, 0.14129359],
#        [0.99721469, 0.00278531],
#        [0.93781552, 0.06218448],
#        [0.41885882, 0.58114118],
#        [0.70025796, 0.29974204],
#        [0.923651  , 0.076349  ],
#        [0.28869492, 0.71130508],
#        [0.52816853, 0.47183147],
#        [0.88004546, 0.11995454],
#        [0.25035116, 0.74964884],
#        [0.28836871, 0.71163129],
#        [0.08994988, 0.91005012],
#        [0.28072607, 0.71927393],
#        [0.85527334, 0.14472666],
#        [0.63401421, 0.36598579],
#        [0.89216059, 0.10783941],
#        [0.86205857, 0.13794143],
#        [0.57807939, 0.42192061],
#        [0.89624477, 0.10375523],
#        [0.04656079, 0.95343921],
#        [0.13271425, 0.86728575],
#        [0.66451489, 0.33548511],
#        [0.89409066, 0.10590934],
#        [0.38025247, 0.61974753],
#        [0.92806775, 0.07193225],
#        [0.80640082, 0.19359918],
#        [0.66113029, 0.33886971],
#        [0.60373895, 0.39626105],
#        [0.78900189, 0.21099811],
#        [0.96677398, 0.03322602],
#        [0.78981058, 0.21018942],
#        [0.77108894, 0.22891106],
#        [0.68750087, 0.31249913],
#        [0.57609738, 0.42390262],
#        [0.12992487, 0.87007513],
#        [0.7985068 , 0.2014932 ],
#        [0.83004692, 0.16995308],
#        [0.80922643, 0.19077357],
#        [0.75707444, 0.24292556],
#        [0.9581509 , 0.0418491 ],
#        [0.36531834, 0.63468166],
#        [0.8030704 , 0.1969296 ],
#        [0.5746185 , 0.4253815 ],
#        [0.47490943, 0.52509057],
#        [0.42501747, 0.57498253],
#        [0.75414033, 0.24585967],
#        [0.7405805 , 0.2594195 ],
#        [0.90235351, 0.09764649],
#        [0.76825397, 0.23174603],
#        [0.96100127, 0.03899873],
#        [0.35053107, 0.64946893],
#        [0.63487891, 0.36512109],
#        [0.85935217, 0.14064783],
#        [0.68064947, 0.31935053],
#        [0.95746658, 0.04253342],
#        [0.23043345, 0.76956655],
#        [0.8888294 , 0.1111706 ],
#        [0.70024069, 0.29975931],
#        [0.36872384, 0.63127616],
#        [0.60499595, 0.39500405],
#        [0.46264924, 0.53735076],
#        [0.37613877, 0.62386123],
#        [0.88655402, 0.11344598],
#        [0.33071761, 0.66928239],
#        [0.89249386, 0.10750614],
#        [0.26344612, 0.73655388],
#        [0.62161368, 0.37838632],
#        [0.66340487, 0.33659513],
#        [0.7037963 , 0.2962037 ],
#        [0.57019878, 0.42980122],
#        [0.77197718, 0.22802282],
#        [0.9504309 , 0.0495691 ],
#        [0.67380581, 0.32619419],
#        [0.64003047, 0.35996953],
#        [0.53673137, 0.46326863],
#        [0.60480767, 0.39519233],
#        [0.62472608, 0.37527392],
#        [0.95952168, 0.04047832],
#        [0.93946316, 0.06053684],
#        [0.24809299, 0.75190701],
#        [0.70782078, 0.29217922],
#        [0.61436868, 0.38563132],
#        [0.85643577, 0.14356423],
#        [0.60701557, 0.39298443],
#        [0.3100209 , 0.6899791 ],
#        [0.7858991 , 0.2141009 ],
#        [0.90528727, 0.09471273],
#        [0.46082985, 0.53917015],
#        [0.92400061, 0.07599939],
#        [0.92282423, 0.07717577],
#        [0.64811092, 0.35188908],
#        [0.90692314, 0.09307686],
#        [0.92571924, 0.07428076],
#        [0.91192415, 0.08807585],
#        [0.86161816, 0.13838184],
#        [0.81226928, 0.18773072],
#        [0.91660093, 0.08339907],
#        [0.31019487, 0.68980513],
#        [0.89205131, 0.10794869],
#        [0.81877447, 0.18122553]])

# %%
fpr2,tpr2,threshold2=roc_curve(y_test2,y_pred_prob_log[:,1])

# %% [markdown]
# # plot roc_curve and find auc_roc_score for all

# %%
plt.figure(figsize=(10,5))

plt.plot(fpr,tpr,label="Tree_Classification")
plt.plot(fpr1,tpr1,color='red',label="KNN_Classification")
plt.plot(fpr2,tpr2,label="Logistic_Classification")
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc='best')

# %%
AUC_score_tree=roc_auc_score(y_test,y_prob_tree[:,1])
print("AUC Score for Tree :",AUC_score_tree)
print()
auc_score_knn=roc_auc_score(y_test1,y_prob_knn[:,1])
print("AUC Score for KNN :",auc_score_knn)
print()
auc_score_logistic=roc_auc_score(y_test2,y_pred_prob_log[:,1])
print("AUC Score for logistic :",auc_score_logistic)
# Out:
# AUC Score for Tree : 0.7813680652217141
#
# AUC Score for KNN : 0.7793795983296878
#
# AUC Score for logistic : 0.8665738715450388
